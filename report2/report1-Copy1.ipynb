# %% [markdown]
# ## Report \#2
# #### 20 Settembre 2020

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
from PIL import Image

# %%
plt.figure(figsize=(30,30))
plt.title("plain")
plt.subplot(131,frameon=False)
plt.imshow(img.imread('boxplain.png'))
plt.axis('off')
plt.subplot(132,frameon=False)
plt.imshow(img.imread('sqplain.png'))
plt.axis('off')
plt.subplot(133,frameon=False)
plt.imshow(img.imread('plain.png'))
plt.axis('off')
# Out:
# (-0.5, 1315.5, 1105.5, -0.5)

# %%
plt.figure(figsize=(18,9))
plt.title("stacking at 0.5z")

plt.subplot(131,frameon=False)
plt.imshow(img.imread('box05stack.png'))
plt.axis('off')
plt.subplot(132,frameon=False)
plt.imshow(img.imread('sq05stack.png'))
plt.axis('off')
plt.subplot(133,frameon=False)
plt.imshow(img.imread('05stack.png'))
plt.axis('off')
# Out:
# (-0.5, 1315.5, 1105.5, -0.5)

# %%
plt.figure(figsize=(18,9))
plt.title("Stacking at 0.2z")


plt.subplot(131,frameon=False)
plt.imshow(img.imread('box02stack.png'))
plt.axis('off')
plt.subplot(132,frameon=False)
plt.imshow(img.imread('sq02stack.png'))
plt.axis('off')
plt.subplot(133,frameon=False)
plt.imshow(img.imread('02stack.png'))
plt.axis('off')
# Out:
# (-0.5, 1315.5, 1105.5, -0.5)

# %%
plt.figure(figsize=(18,9))
plt.title("Stacking at 05z and 07z")

plt.subplot(131,frameon=False)
plt.imshow(img.imread('box0507stack.png'))
plt.axis('off')
plt.subplot(132,frameon=False)
plt.imshow(img.imread('sq0507stack.png'))
plt.axis('off')
plt.subplot(133,frameon=False)
plt.imshow(img.imread('0507stack.png'))
plt.axis('off')
# Out:
# (-0.5, 1315.5, 1105.5, -0.5)

# %%
plt.figure(figsize=(18,9))
plt.title("stacking at 09z")

plt.subplot(131,frameon=False)
plt.imshow(img.imread('box09stack.png'))
plt.axis('off')
plt.subplot(132,frameon=False)
plt.imshow(img.imread('sq09stack.png'))
plt.axis('off')
plt.subplot(133,frameon=False)
plt.imshow(img.imread('09stack.png'))
plt.axis('off')
# Out:
# (-0.5, 1315.5, 1105.5, -0.5)

# %%
plt.figure(figsize=(18,9))
plt.title("5 vacancies, melted")

plt.subplot(131,frameon=False)
plt.imshow(img.imread('box5vac.png'))
plt.axis('off')
plt.subplot(132,frameon=False)
plt.imshow(img.imread('sq5vac.png'))
plt.axis('off')
plt.subplot(133,frameon=False)
plt.imshow(img.imread('5vac.png'))
plt.axis('off')
# Out:
# (-0.5, 1315.5, 1105.5, -0.5)

# %%
plt.figure(figsize=(18,9))
plt.title("5 vacancies,not melted")

plt.subplot(131,frameon=False)
plt.imshow(img.imread('box5vacro.png'))
plt.axis('off')
plt.subplot(132,frameon=False)
plt.imshow(img.imread('sq5vacro.png'))
plt.axis('off')
plt.subplot(133,frameon=False)
plt.imshow(img.imread('5vacro.png'))
plt.axis('off')
# Out:
# (-0.5, 1315.5, 1105.5, -0.5)

# %% [markdown]
# ### CCA high res:
# 2000x2000px

# %%
plt.figure(figsize=(18,18))
plt.subplot(221,frameon=False)
plt.imshow(img.imread('sqhighres.png'))
plt.axis('off')
plt.subplot(222,frameon=False)
plt.imshow(img.imread('sqlowres.png'))
plt.axis('off')
plt.subplot(223,frameon=False)
plt.imshow(img.imread('highres.png'))
plt.axis('off')
plt.subplot(224,frameon=False)
plt.imshow(img.imread('lowres.png'))
plt.axis('off')
plt.show()

plt.figure(figsize=(18,9))
plt.title("5 vacancies,not melted")
plt.subplot(111,frameon=False)
plt.imshow(img.imread('boxhighres.png'))##==boxlowres
plt.show()
